# %% [markdown]
# <a href="https://colab.research.google.com/github/vikhyat-3/Start/blob/main/OCR_shi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow==5.4.1
from PIL import Image
# !pip install gTTS
# !pip install playsound
# !sudo apt install tesseract-ocr
# !pip install pytesseract --quiet
# !pip install pygobject
# Out:
# ...
#   Using cached Pillow-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.1.0
#     Uninstalling Pillow-9.1.0:
#       Successfully uninstalled Pillow-9.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytesseract 0.3.9 requires Pillow>=8.0.0, but you have pillow 5.4.1 which is incompatible.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 5.4.1 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...

# %%
import cv2
import pytesseract as pt
from google.colab.patches import cv2_imshow
def Text_to_speech(text_msg):
    speech = gTTS(text = text_msg)
    speech.save('do.mp3')

# %%
from PIL import Image
from gtts import gTTS

# %%
img=cv2.imread("/content/OIP.jpg")
img
# Out:
# array([[[222, 206, 194],
#         [222, 206, 194],
#         [222, 206, 194],
#         ...,
#         [190, 127,  46],
#         [190, 127,  46],
#         [190, 127,  46]],
#
#        [[222, 206, 194],
#         [222, 206, 194],
#         [222, 206, 194],
#         ...,
#         [192, 131,  51],
#         [193, 132,  52],
#         [193, 132,  52]],
#
#        [[223, 205, 194],
#         [223, 205, 194],
#         [223, 205, 194],
#         ...,
#         [197, 137,  61],
#         [198, 138,  62],
#         [198, 138,  62]],
#
#        ...,
#
#        [[212, 197, 181],
#         [212, 198, 180],
#         [213, 197, 181],
#         ...,
#         [203, 173, 144],
#         [207, 175, 146],
#         [208, 177, 146]],
#
#        [[213, 197, 180],
#         [212, 197, 178],
#         [214, 196, 179],
#         ...,
#         [203, 173, 146],
#         [203, 171, 142],
#         [207, 175, 146]],
#
#        [[212, 197, 178],
#         [212, 197, 178],
#         [214, 197, 178],
# ...

# %%
from PIL import Image
print('PIL',Image.__version__)
# Out:
# PIL 9.1.0

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=680x480>

# %%
op=pt.image_to_string(img)
Text_to_speech(op)
